# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

G.add_node('Mathilda')
G.add_node('Sacha')

# %%
G2 = nx.Graph()

G2.add_node('Killian')
G2.add_node('Celian')

# %%
plt.figure(1)
nx.draw(G)

plt.figure(2)
nx.draw(G2, node_color = 'red')

plt.show()
